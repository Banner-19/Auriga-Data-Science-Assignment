# %%
import cv2
import numpy as np
from ultralytics import YOLO

# %% [markdown]
# # Load the YOLOv8 model

# %%
model = YOLO("yolov8n.pt")

# %% [markdown]
# # Initialize video capture

# %%
video_path = 'D:/Internship Assignments/Auriga Tech Solutions Private Limited/Traffic/traffic_vid.mp4'
cap = cv2.VideoCapture(video_path)

# %% [markdown]
# # Define stop line position (modify based on your video)

# %%
original_stop_line_position = 500

# %%
display_width, display_height = 640, 480

# %% [markdown]
# # Initialize car counter

# %%
car_count = 0
detected_cars = []

# %% [markdown]
# # Function to check if a car is crossing the stop line

# %%
def is_crossing_stop_line(y1, y2, stop_line_position):
    return y1 < stop_line_position < y2

# %%
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Get original frame dimensions
    original_height, original_width, _ = frame.shape

    # Calculate the scaling factor
    scale_x = display_width / original_width
    scale_y = display_height / original_height

    # Scale the stop line position
    stop_line_position = int(original_stop_line_position * scale_y)

    # Run YOLOv8 on the frame
    results = model(frame)

    # Resize the frame for display
    frame_resized = cv2.resize(frame, (display_width, display_height))

    # Extract bounding boxes and class labels from YOLO results
    for result in results[0].boxes:
        x1, y1, x2, y2 = map(int, result.xyxy[0])
        cls = int(result.cls)
        if cls == 2:  # Class 2 corresponds to 'car' in COCO dataset
            car_id = f'{x1}_{y1}_{x2}_{y2}'
            if is_crossing_stop_line(y1, y2, stop_line_position):
                if car_id not in detected_cars:
                    detected_cars.append(car_id)
                    car_count += 1
                # Draw bounding box in a distinct color for cars crossing the stop line
                cv2.rectangle(frame_resized, (int(x1*scale_x), int(y1*scale_y)), (int(x2*scale_x), int(y2*scale_y)), (0, 0, 255), 2)
                cv2.putText(frame_resized, 'Car (counted)', (int(x1*scale_x), int(y1*scale_y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
            else:
                # Draw bounding box for other cars
                cv2.rectangle(frame_resized, (int(x1*scale_x), int(y1*scale_y)), (int(x2*scale_x), int(y2*scale_y)), (0, 255, 0), 2)
                cv2.putText(frame_resized, 'Car', (int(x1*scale_x), int(y1*scale_y) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Draw the stop line
    cv2.line(frame_resized, (0, stop_line_position), (display_width, stop_line_position), (255, 0, 0), 2)

    # Display car count on the resized frame
    cv2.putText(frame_resized, f'Car count: {car_count}', (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Show the resized frame
    cv2.imshow('Frame (Resized)', frame_resized)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 384x640 8 cars, 8 traffic lights, 389.9ms
# Speed: 16.5ms preprocess, 389.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 traffic lights, 300.8ms
# Speed: 8.6ms preprocess, 300.8ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 6 traffic lights, 281.9ms
# Speed: 0.0ms preprocess, 281.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 233.1ms
# Speed: 0.0ms preprocess, 233.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 traffic lights, 265.9ms
# Speed: 0.0ms preprocess, 265.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 traffic lights, 249.3ms
# Speed: 0.0ms preprocess, 249.3ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 traffic lights, 249.9ms
# Speed: 15.6ms preprocess, 249.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 traffic lights, 259.5ms
# Speed: 0.0ms preprocess, 259.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 traffic lights, 234.0ms
# Speed: 0.0ms preprocess, 234.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 319.8ms
# Speed: 0.0ms preprocess, 319.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 420.4ms
# Speed: 7.4ms preprocess, 420.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 473.4ms
# Speed: 0.0ms preprocess, 473.4ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 traffic lights, 253.6ms
# Speed: 4.8ms preprocess, 253.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 9 traffic lights, 350.1ms
# Speed: 14.9ms preprocess, 350.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 8
ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 191.6ms
# Speed: 0.0ms preprocess, 191.6ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 traffic lights, 206.2ms
# Speed: 10.0ms preprocess, 206.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 5 traffic lights, 206.4ms
# Speed: 10.4ms preprocess, 206.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 5 traffic lights, 193.3ms
# Speed: 0.0ms preprocess, 193.3ms inference, 16.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 193.4ms
# Speed: 0.0ms preprocess, 193.4ms inference, 16.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 208.6ms
# Speed: 0.0ms preprocess, 208.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 172.6ms
# Speed: 11.4ms preprocess, 172.6ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 6 traffic lights, 213.6ms
# Speed: 0.0ms preprocess, 213.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 200.0ms
# Speed: 4.4ms preprocess, 200.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 216.5ms
# Speed: 0.0ms preprocess, 216.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 174.9ms
# Speed: 8.0ms preprocess, 174.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 341.1ms
# Speed: 0.0ms preprocess, 341.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 5 traffic lights, 299.8ms
# Speed: 0.2ms preprocess, 299.8ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 5 traffic lights, 357.4ms
# Speed: 5.0ms preprocess, 357.4ms inference, 16.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 traffic lights, 326.2ms
# Speed: 4.1ms preprocess, 326.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 352.2ms
# Speed: 6.3ms preprocess, 352.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 196.9ms
# Speed: 3.3ms preprocess, 196.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 5 traffic lights, 210.0ms
# Speed: 0.0ms preprocess, 210.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 190.5ms
# Speed: 10.1ms preprocess, 190.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 6 traffic lights, 283.4ms
# Speed: 8.6ms preprocess, 283.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 196.3ms
# Speed: 0.0ms preprocess, 196.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 210.0ms
# Speed: 0.0ms preprocess, 210.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 5 traffic lights, 175.9ms
# Speed: 0.0ms preprocess, 175.9ms inference, 16.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 6 traffic lights, 201.4ms
# Speed: 0.0ms preprocess, 201.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 232.0ms
# Speed: 0.0ms preprocess, 232.0ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 226.7ms
# Speed: 0.0ms preprocess, 226.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 5 traffic lights, 224.7ms
# Speed: 0.0ms preprocess, 224.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 204.5ms
# Speed: 11.2ms preprocess, 204.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 176.6ms
# Speed: 0.0ms preprocess, 176.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 204.1ms
# Speed: 0.0ms preprocess, 204.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 362.9ms
# Speed: 0.0ms preprocess, 362.9ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 277.3ms
# Speed: 1.8ms preprocess, 277.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 5 traffic lights, 214.8ms
# Speed: 8.1ms preprocess, 214.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 4 traffic lights, 189.9ms
# Speed: 9.8ms preprocess, 189.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 4 traffic lights, 192.3ms
# Speed: 0.0ms preprocess, 192.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 188.9ms
# Speed: 10.6ms preprocess, 188.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 178.5ms
# Speed: 5.5ms preprocess, 178.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 357.9ms
# Speed: 0.0ms preprocess, 357.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 5 traffic lights, 193.2ms
# Speed: 0.0ms preprocess, 193.2ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 5 traffic lights, 226.3ms
# ...
#
# 0: 384x640 9 cars, 5 traffic lights, 205.8ms
# Speed: 10.1ms preprocess, 205.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 traffic lights, 246.3ms
# Speed: 0.0ms preprocess, 246.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 202.3ms
# Speed: 6.4ms preprocess, 202.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 traffic lights, 177.3ms
# Speed: 0.0ms preprocess, 177.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 191.9ms
# Speed: 0.0ms preprocess, 191.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 6 traffic lights, 203.9ms
# Speed: 11.4ms preprocess, 203.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 traffic lights, 203.6ms
# Speed: 3.3ms preprocess, 203.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 traffic lights, 200.1ms
# Speed: 0.0ms preprocess, 200.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 6 traffic lights, 304.8ms
# Speed: 0.0ms preprocess, 304.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 7 traffic lights, 289.3ms
# Speed: 2.6ms preprocess, 289.3ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 7 traffic lights, 254.9ms
# Speed: 3.8ms preprocess, 254.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 6 traffic lights, 220.9ms
# Speed: 0.0ms preprocess, 220.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 6 traffic lights, 203.4ms
# Speed: 2.5ms preprocess, 203.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 5 traffic lights, 275.6ms
# Speed: 4.3ms preprocess, 275.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 4 traffic lights, 290.8ms
# Speed: 6.8ms preprocess, 290.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 11 cars, 5 traffic lights, 276.0ms
# Speed: 6.7ms preprocess, 276.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 4 traffic lights, 276.3ms
# Speed: 0.3ms preprocess, 276.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 4 traffic lights, 238.8ms
# Speed: 4.3ms preprocess, 238.8ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 299.4ms
# Speed: 8.9ms preprocess, 299.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 287.4ms
# Speed: 0.0ms preprocess, 287.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 traffic lights, 383.1ms
# Speed: 6.1ms preprocess, 383.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 4 traffic lights, 349.8ms
# Speed: 8.1ms preprocess, 349.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 6 traffic lights, 207.9ms
# Speed: 8.1ms preprocess, 207.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 6 traffic lights, 228.4ms
# Speed: 8.0ms preprocess, 228.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 5 traffic lights, 357.7ms
# Speed: 0.0ms preprocess, 357.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 5 traffic lights, 281.7ms
# Speed: 2.6ms preprocess, 281.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 4 traffic lights, 238.2ms
# Speed: 2.4ms preprocess, 238.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 5 traffic lights, 279.4ms
# Speed: 0.0ms preprocess, 279.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 5 traffic lights, 224.0ms
# Speed: 7.6ms preprocess, 224.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 3 traffic lights, 341.2ms
# Speed: 11.1ms preprocess, 341.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 5 traffic lights, 286.6ms
# Speed: 1.6ms preprocess, 286.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 5 traffic lights, 426.4ms
# Speed: 8.0ms preprocess, 426.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 3 traffic lights, 279.6ms
# Speed: 7.2ms preprocess, 279.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 4 traffic lights, 295.1ms
# Speed: 4.4ms preprocess, 295.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 6 traffic lights, 314.8ms
# Speed: 5.8ms preprocess, 314.8ms inference, 15.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 17
#      14 stop_line_position = int(original_stop_line_position * scale_y)
#      16 # Run YOLOv8 on the frame
# ---> 17 results = model(frame)
#      19 # Resize the frame for display
#      20 frame_resized = cv2.resize(frame, (display_width, display_height))
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     154 def __call__(
#     155     self,
#     156     source: Union[str, Path, int, list, tuple, np.ndarray, torch.Tensor] = None,
#     157     stream: bool = False,
#     158     **kwargs,
#     159 ) -> list:
#     160     """
#     161     An alias for the predict method, enabling the model instance to be callable.
#     162
#    (...)
#     175         (List[ultralytics.engine.results.Results]): A list of prediction results, encapsulated in the Results class.
#     176     """
# --> 177     return self.predict(source, stream, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:453, in Model.predict(self, source, stream, predictor, **kwargs)
#     451 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     452     self.predictor.set_prompts(prompts)
# --> 453 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:248, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     246 # Inference
#     247 with profilers[1]:
# --> 248     preds = self.inference(im, *args, **kwargs)
#     249     if self.args.embed:
#     250         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\autobackend.py:453, in AutoBackend.forward(self, im, augment, visualize, embed)
#     451 # PyTorch
#     452 if self.pt or self.nn_module:
# --> 453     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     455 # TorchScript
#     456 elif self.jit:
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:89, in BaseModel.forward(self, x, *args, **kwargs)
#      87 if isinstance(x, dict):  # for cases of training and validating while training.
#      88     return self.loss(x, *args, **kwargs)
# ---> 89 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:107, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     105 if augment:
#     106     return self._predict_augment(x)
# --> 107 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:128, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     126 if profile:
#     127     self._profile_one_layer(m, x, dt)
# --> 128 x = m(x)  # run
#     129 y.append(x if m.i in self.save else None)  # save output
#     130 if visualize:
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\modules\block.py:231, in C2f.forward(self, x)
#     229 y = list(self.cv1(x).chunk(2, 1))
#     230 y.extend(m(y[-1]) for m in self.m)
# --> 231 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\activation.py:396, in SiLU.forward(self, input)
#     395 def forward(self, input: Tensor) -> Tensor:
# --> 396     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\Bhaskar Banerjee\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\functional.py:2101, in silu(input, inplace)
#    2099     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2100 if inplace:
# -> 2101     return torch._C._nn.silu_(input)
#    2102 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %%
print(f'Total car count: {car_count}')
# Out:
# Total car count: 0
